# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
n=7 #no. of people
p=0.6 #probability that one person will pay the loan

# %%
k = np.arange(0,8)
k
# Out:
# array([0, 1, 2, 3, 4, 5, 6, 7])

# %%
# pmf - probability mass function
binomial = stats.binom.pmf(k,n,p)

# %%
binomial
# Out:
# array([0.0016384, 0.0172032, 0.0774144, 0.193536 , 0.290304 , 0.2612736,
#        0.1306368, 0.0279936])

# %% [markdown]
# array([0.0016384, # probability that no person will pay the loan
#        0.0172032, # probability that 1 person will pay the loan
#        0.0774144, # probability that 2 person will pay the loan
#        0.193536 , # probability that 3 person will pay the loan
#        0.290304 , # probability that 4 person will pay the loan
#        0.2612736, # probability that 5 person will pay the loan
#        0.1306368, # probability that 6 person will pay the loan
#        0.0279936  # probability that 7 person will pay the loan
#       ])

# %%
plt.plot(k,binomial, 'o-')
plt.title('Binomial: n-%i, p-%.2f' % (n,p), fontsize=15)
plt.xlabel('Number of successes')
plt.ylabel('Probability of success')
plt.show()

# %%
sum(binomial)
# Out:
# 1.0000000000000004
